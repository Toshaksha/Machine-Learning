# %% [markdown]
# # ***Houston Housing Price Prediction using Random Forest Regressor***
#
# ## Objective:
# Predict the unformatted price of a property in Houston based on features like zestimate, area, beds, etc., using a Random Forest Regressor.
#
# ## Workflow Overview:
# - **Import Dependencies** – Load required Python libraries
# - **Load & Explore Data** – Load JSON housing data and inspect structure
# - **Data Cleaning & Preprocessing** – Drop irrelevant columns, impute missing values
# - **Feature Engineering** – Encode categorical variables using one-hot encoding
# - **Train-Test Split** – Divide data into training and testing sets
# - **Model Training** – Train a Random Forest Regressor
# - **Model Evaluation** – Evaluate model using MAE (Mean Absolute Error)
# - **Feature Importance** – Identify top predictors
# - **Baseline Metrics** – Compare MAE to average house price
#
# ## Problem Type:
# - Regression Problem
# - Target Variable: unformattedPrice (continuous value representing house price in USD)
#
# ## Dataset:
# - Source: Zillow Houston Housing Market Dataset (2024)
# - Format: JSON
# - Rows: ~18,000+ properties
# - Features: Street address, beds, baths, Zestimate, area, price, images, and many binary attributes

# %% [markdown]
# ### Step 1: Import Dependencies
# Load libraries for data processing, modeling, and evaluation.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np

# %% [markdown]
# ### Step 2: Load & Explore the Dataset
# Read the JSON file and understand its structure and contents.

# %%
# Unzip the dataset
# !unzip -q houston_housing_market_2024_light.json.zip -d houston_house_data

# %%
# List files to verify
# !ls houston_house_data
# Out:
# 'houston_housing market 2024_light.json'

# %%
# Load the lighter JSON file
house_data = pd.read_json("/content/houston_house_data/houston_housing market 2024_light.json")

# %% [markdown]
# Initial Structure and stats of data

# %%
house_data.head()
# Out:
#         zpid         id rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0  305340899  305340899         ForSale           For Sale by Agent
# 1  160934721  160934721         ForSale           For Sale by Agent
# 2  121106557  121106557         ForSale           For Sale by Agent
# 3   28549516   28549516         ForSale           For Sale by Agent
# 4  123238565  123238565         ForSale           For Sale by Agent
#
#                                               imgSrc  hasImage  \
# 0  https://photos.zillowstatic.com/fp/c6c062dff72...       1.0
# 1  https://photos.zillowstatic.com/fp/dca8e79a0d4...       1.0
# 2  https://photos.zillowstatic.com/fp/5d7fc370754...       1.0
# 3  https://photos.zillowstatic.com/fp/f7c3f5735ac...       1.0
# 4  https://photos.zillowstatic.com/fp/274024ea250...       1.0
#
#                                            detailUrl statusType  \
# 0  https://www.zillow.com/homedetails/13234-Valle...   FOR_SALE
# 1  https://www.zillow.com/homedetails/12235-Green...   FOR_SALE
# 2  https://www.zillow.com/homedetails/13807-Bend-...   FOR_SALE
# 3  https://www.zillow.com/homedetails/14606-Kings...   FOR_SALE
# 4  https://www.zillow.com/homedetails/14434-Mount...   FOR_SALE
#
#        statusText countryCurrency  ... builderName  streetViewURL  \
# 0  House for sale               $  ...         NaN            NaN
# 1  House for sale               $  ...         NaN            NaN
# 2  House for sale               $  ...         NaN            NaN
# 3  House for sale               $  ...         NaN            NaN
# 4  House for sale               $  ...         NaN            NaN
#
#   streetViewMetadataURL isPropertyResultCDP flexFieldText flexFieldType  \
# 0                   NaN                 NaN           NaN           NaN
# 1                   NaN                 NaN           NaN           NaN
# 2                   NaN                 NaN           NaN           NaN
# 3                   NaN                 NaN           NaN           NaN
# 4                   NaN                 NaN           NaN           NaN
#
#    info3String  info6String  info2String  availabilityDate
# 0          NaN          NaN          NaN               NaN
# 1          NaN          NaN          NaN               NaN
# 2          NaN          NaN          NaN               NaN
# 3          NaN          NaN          NaN               NaN
# 4          NaN          NaN          NaN               NaN
#
# [5 rows x 58 columns]

# %%
house_data.shape
# Out:
# (25948, 58)

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25948 entries, 0 to 25947
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   zpid                         25948 non-null  int64
#  1   id                           25948 non-null  int64
#  2   rawHomeStatusCd              25948 non-null  object
#  3   marketingStatusSimplifiedCd  25948 non-null  object
#  4   imgSrc                       25948 non-null  object
#  5   hasImage                     25839 non-null  float64
#  6   detailUrl                    25948 non-null  object
#  7   statusType                   25948 non-null  object
#  8   statusText                   25948 non-null  object
#  9   countryCurrency              25948 non-null  object
#  10  price                        25948 non-null  object
#  11  unformattedPrice             25948 non-null  int64
#  12  address                      25948 non-null  object
#  13  addressStreet                25948 non-null  object
#  14  addressCity                  25948 non-null  object
#  15  addressState                 25948 non-null  object
#  16  addressZipcode               25948 non-null  int64
#  17  isUndisclosedAddress         25948 non-null  bool
#  18  beds                         22795 non-null  float64
#  19  baths                        25911 non-null  float64
#  20  area                         22792 non-null  float64
#  21  latLong                      25948 non-null  object
#  22  isZillowOwned                25948 non-null  bool
#  23  variableData                 13831 non-null  object
#  24  hdpData                      25948 non-null  object
#  25  isSaved                      25948 non-null  bool
#  26  isUserClaimingOwner          25948 non-null  bool
#  27  isUserConfirmedClaim         25948 non-null  bool
#  28  pgapt                        25948 non-null  object
#  29  sgapt                        25948 non-null  object
#  30  zestimate                    21521 non-null  float64
#  31  shouldShowZestimateAsPrice   25948 non-null  bool
#  32  has3DModel                   25948 non-null  bool
#  33  hasVideo                     25948 non-null  bool
#  34  isHomeRec                    25948 non-null  bool
#  35  hasAdditionalAttributions    25948 non-null  bool
#  36  isFeaturedListing            25948 non-null  bool
#  37  isShowcaseListing            25948 non-null  bool
#  38  list                         25948 non-null  bool
#  39  relaxed                      25948 non-null  bool
#  40  brokerName                   21792 non-null  object
#  41  carouselPhotos               25859 non-null  object
#  42  hasOpenHouse                 1235 non-null   float64
#  43  openHouseStartDate           1235 non-null   object
#  44  openHouseEndDate             1235 non-null   object
#  45  openHouseDescription         1235 non-null   object
#  46  lotAreaString                3067 non-null   object
#  47  providerListingId            5791 non-null   float64
#  48  builderName                  7887 non-null   object
#  49  streetViewURL                109 non-null    object
#  50  streetViewMetadataURL        109 non-null    object
#  51  isPropertyResultCDP          3400 non-null   float64
#  52  flexFieldText                12117 non-null  object
#  53  flexFieldType                12117 non-null  object
#  54  info3String                  23 non-null     object
#  55  info6String                  13 non-null     object
#  56  info2String                  1 non-null      object
#  57  availabilityDate             9 non-null      object
# dtypes: bool(14), float64(8), int64(4), object(32)
# memory usage: 9.1+ MB

# %%
house_data.isnull().sum()
# Out:
# zpid                               0
# id                                 0
# rawHomeStatusCd                    0
# marketingStatusSimplifiedCd        0
# imgSrc                             0
# hasImage                         109
# detailUrl                          0
# statusType                         0
# statusText                         0
# countryCurrency                    0
# price                              0
# unformattedPrice                   0
# address                            0
# addressStreet                      0
# addressCity                        0
# addressState                       0
# addressZipcode                     0
# isUndisclosedAddress               0
# beds                            3153
# baths                             37
# area                            3156
# latLong                            0
# isZillowOwned                      0
# variableData                   12117
# hdpData                            0
# isSaved                            0
# isUserClaimingOwner                0
# isUserConfirmedClaim               0
# pgapt                              0
# sgapt                              0
# zestimate                       4427
# shouldShowZestimateAsPrice         0
# has3DModel                         0
# hasVideo                           0
# isHomeRec                          0
# hasAdditionalAttributions          0
# isFeaturedListing                  0
# isShowcaseListing                  0
# list                               0
# relaxed                            0
# brokerName                      4156
# carouselPhotos                    89
# hasOpenHouse                   24713
# openHouseStartDate             24713
# openHouseEndDate               24713
# openHouseDescription           24713
# lotAreaString                  22881
# providerListingId              20157
# builderName                    18061
# streetViewURL                  25839
# streetViewMetadataURL          25839
# isPropertyResultCDP            22548
# flexFieldText                  13831
# flexFieldType                  13831
# info3String                    25925
# info6String                    25935
# info2String                    25947
# availabilityDate               25939
# dtype: int64

# %% [markdown]
# ### Step 3: Data Cleaning & Preprocessing
# Drop irrelevant columns and handle missing values based on data skewness.

# %%
# dropping columns with high missing values
columns_to_drop  = ["variableData", "hasOpenHouse" ,"openHouseStartDate" ,
                    "openHouseEndDate" ,"openHouseDescription" ,"lotAreaString"
                    ,"providerListingId" ,"builderName" ,"streetViewURL"
                    ,"streetViewMetadataURL" ,"isPropertyResultCDP" ,"flexFieldText"
                    ,"flexFieldType" ,"info3String" ,"info6String"
                    ,"info2String" , "availabilityDate"]


house_data.drop(columns = columns_to_drop, inplace = True)

# %%
# Correlation matrix
correlation = house_data.corr(numeric_only=True)

# Show correlation with target
correlation['unformattedPrice'].sort_values(ascending=False)
# Out:
# unformattedPrice              1.000000
# zestimate                     0.996109
# area                          0.623328
# baths                         0.269873
# beds                          0.267893
# hasVideo                      0.024171
# isShowcaseListing             0.016465
# zpid                          0.003945
# id                            0.003945
# hasAdditionalAttributions    -0.000671
# addressZipcode               -0.016223
# has3DModel                   -0.039385
# hasImage                           NaN
# isUndisclosedAddress               NaN
# isZillowOwned                      NaN
# isSaved                            NaN
# isUserClaimingOwner                NaN
# isUserConfirmedClaim               NaN
# shouldShowZestimateAsPrice         NaN
# isHomeRec                          NaN
# isFeaturedListing                  NaN
# list                               NaN
# relaxed                            NaN
# Name: unformattedPrice, dtype: float64

# %%
# Check percentage of missing values
missing_percent = house_data.isnull().mean().sort_values(ascending=False) * 100
print(missing_percent)
# Out:
# zestimate                      17.061045
# brokerName                     16.016649
# area                           12.162787
# beds                           12.151226
# hasImage                        0.420071
# carouselPhotos                  0.342994
# baths                           0.142593
# zpid                            0.000000
# id                              0.000000
# statusText                      0.000000
# statusType                      0.000000
# detailUrl                       0.000000
# imgSrc                          0.000000
# rawHomeStatusCd                 0.000000
# marketingStatusSimplifiedCd     0.000000
# addressStreet                   0.000000
# countryCurrency                 0.000000
# addressZipcode                  0.000000
# addressState                    0.000000
# addressCity                     0.000000
# isUndisclosedAddress            0.000000
# latLong                         0.000000
# price                           0.000000
# unformattedPrice                0.000000
# address                         0.000000
# isSaved                         0.000000
# hdpData                         0.000000
# isZillowOwned                   0.000000
# isUserClaimingOwner             0.000000
# sgapt                           0.000000
# shouldShowZestimateAsPrice      0.000000
# pgapt                           0.000000
# isUserConfirmedClaim            0.000000
# hasVideo                        0.000000
# has3DModel                      0.000000
# isHomeRec                       0.000000
# hasAdditionalAttributions       0.000000
# isShowcaseListing               0.000000
# isFeaturedListing               0.000000
# relaxed                         0.000000
# list                            0.000000
# dtype: float64

# %%
# Finding Skewness to determine the statistical measure to imputate
print(f"Bed Skewness: {house_data['beds'].skew()}")
print(f"area Skewness: {house_data['area'].skew()}")
print(f"zestimate Skewness: {house_data['zestimate'].skew()}")
print(f"baths Skewness: {house_data['baths'].skew()}")
# Out:
# Bed Skewness: 0.7797275640195557
# area Skewness: 14.093616987829206
# zestimate Skewness: 15.694127856538481
# baths Skewness: 0.8159236495361571

# %% [markdown]
# **Interpretation:**
# - . 0 → perfectly symmetrical
# - . > 0.5 → moderate right-skewed
# - . > 1 → highly right-skewed
# - . < -0.5 → moderate left-skewed
# - . < -1 → highly left-skewed

# %% [markdown]
# **Imputate Missing Values**

# %%
# Numerical Columns (use median)
house_data['zestimate'].fillna(house_data['zestimate'].median(), inplace=True)
house_data['area'].fillna(house_data['area'].median(), inplace=True)
house_data['beds'].fillna(house_data['beds'].median(), inplace=True)
house_data['baths'].fillna(house_data['baths'].median(), inplace=True)
# Out:
# /tmp/ipython-input-17-3388117426.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['zestimate'].fillna(house_data['zestimate'].median(), inplace=True)
# /tmp/ipython-input-17-3388117426.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['area'].fillna(house_data['area'].median(), inplace=True)
# /tmp/ipython-input-17-3388117426.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['beds'].fillna(house_data['beds'].median(), inplace=True)
# /tmp/ipython-input-17-3388117426.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['baths'].fillna(house_data['baths'].median(), inplace=True)

# %%
# Categorical/Binary Columns (use mode)
house_data['brokerName'].fillna(house_data['brokerName'].mode()[0], inplace=True)
house_data['hasImage'].fillna(house_data['hasImage'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-18-726873346.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['brokerName'].fillna(house_data['brokerName'].mode()[0], inplace=True)
# /tmp/ipython-input-18-726873346.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   house_data['hasImage'].fillna(house_data['hasImage'].mode()[0], inplace=True)

# %% [markdown]
# Code	Meaning
# - **.mode()**:- 	Returns a Series of most frequent values (could be 1 or more).
# - **.mode()[0]**:- 	Picks the first mode, suitable for filling in one value.

# %%
# drop irrelevant columns
house_data.drop(columns=['carouselPhotos'], inplace=True)

# %%
print(house_data.isnull().sum())
# Out:
# zpid                           0
# id                             0
# rawHomeStatusCd                0
# marketingStatusSimplifiedCd    0
# imgSrc                         0
# hasImage                       0
# detailUrl                      0
# statusType                     0
# statusText                     0
# countryCurrency                0
# price                          0
# unformattedPrice               0
# address                        0
# addressStreet                  0
# addressCity                    0
# addressState                   0
# addressZipcode                 0
# isUndisclosedAddress           0
# beds                           0
# baths                          0
# area                           0
# latLong                        0
# isZillowOwned                  0
# hdpData                        0
# isSaved                        0
# isUserClaimingOwner            0
# isUserConfirmedClaim           0
# pgapt                          0
# sgapt                          0
# zestimate                      0
# shouldShowZestimateAsPrice     0
# has3DModel                     0
# hasVideo                       0
# isHomeRec                      0
# hasAdditionalAttributions      0
# isFeaturedListing              0
# isShowcaseListing              0
# list                           0
# relaxed                        0
# brokerName                     0
# dtype: int64

# %%
house_data.shape
# Out:
# (25948, 40)

# %% [markdown]
# ### Step 4: Feature Engineering
# Remove unsupported (list/dict) columns and encode remaining categorical features.

# %%
# One-hot encoding for categorical columns
house_model = house_data.copy()

# Drop columns that contain lists or dicts
for col in house_model.columns:
    if house_model[col].apply(lambda x: isinstance(x, (dict, list))).any():
        print(f"Dropping column with dict/list: {col}")
        house_model.drop(columns=[col], inplace=True)
# Out:
# Dropping column with dict/list: latLong
# Dropping column with dict/list: hdpData

# %%
# Select object-type columns
categorical_cols = house_model.select_dtypes(include='object').columns

# Perform one-hot encoding
house_model_encoded = pd.get_dummies(house_model, columns=categorical_cols, drop_first=True)

# %% [markdown]
# ### Step 5: Split Features and Target
# Separate input features (X) from the target price (Y).

# %%
# Downsample to 2,000 rows to avoid memory issues
house_model_sampled = house_model_encoded.sample(n=2000, random_state=42)

# %%
# Seprate features and target
X = house_model_sampled.drop(columns = 'unformattedPrice' , axis = 1)
Y = house_model_sampled['unformattedPrice']

# %% [markdown]
# ### Step 6: Train-Test Split
# Split data into 80% training and 20% test set.

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X, Y , test_size=0.2 , random_state= 0)

# %% [markdown]
# ### Step 7: Train Random Forest Model
# Train a Random Forest Regressor on the training data.

# %%
# Train Random Forest
rf = RandomForestRegressor(n_estimators=30, max_depth=10, random_state=42)
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=30, random_state=42)

# %%
# Predict
y_pred = rf.predict(X_test)

# %% [markdown]
# **Why Random Forest?**
# - Handles non-linear relationships well
# - Robust to outliers and missing values
# - Works well with mixed feature types
# - Provides feature importance
# - Requires minimal preprocessing
# - A strong baseline model for tabular regression

# %% [markdown]
# ### Step 8: Model Evaluation
# Evaluate model performance using Mean Absolute Error (MAE).

# %%
mae = mean_absolute_error(Y_test, y_pred)
print(f"MAE on test set: ${mae:,.2f}")
# Out:
# MAE on test set: $111,063.29

# %% [markdown]
# ### Step 9: Feature Importance
# Identify which features had the most impact on prediction.

# %%
# Feature importances from previous RF model
importances = rf.feature_importances_
features = X_train.columns
importance_series = pd.Series(importances, index=features).sort_values(ascending=False)
print(importance_series.head(20))
# Out:
# zestimate                                                                                           0.516123
# address_0 Fm 762 Rd, Richmond, TX 77469                                                             0.079872
# addressStreet_0 Fm 762 Rd                                                                           0.069252
# price_$15,500,000                                                                                   0.056752
# detailUrl_https://www.zillow.com/homedetails/0-Fm-762-Rd-Richmond-TX-77469/2066674469_zpid/         0.054338
# imgSrc_https://photos.zillowstatic.com/fp/61e50b4c65fe1a8cb2e94a995fbfc1d6-p_e.jpg                  0.022578
# addressStreet_2819 Newhoff St                                                                       0.019676
# detailUrl_https://www.zillow.com/homedetails/2819-Newhoff-St-Houston-TX-77026/27800263_zpid/        0.016456
# imgSrc_https://photos.zillowstatic.com/fp/34982b4245454703e0a1510a029d57fb-p_e.jpg                  0.013489
# price_$7,200,000                                                                                    0.011850
# address_2819 Newhoff St, Houston, TX 77026                                                          0.010487
# detailUrl_https://www.zillow.com/homedetails/10717-Cullen-Blvd-Houston-TX-77047/2058223681_zpid/    0.007568
# address_10717 Cullen Blvd, Houston, TX 77047                                                        0.007119
# area                                                                                                0.006128
# baths                                                                                               0.005216
# imgSrc_https://photos.zillowstatic.com/fp/f046c44d01163006e0658f4e74682098-p_e.jpg                  0.004388
# brokerName_Texas Fast Realty LLC                                                                    0.004376
# brokerName_B E Henson & Associates                                                                  0.004188
# detailUrl_https://www.zillow.com/homedetails/6830-Mykawa-Rd-Houston-TX-77033/2096654440_zpid/       0.003882
# detailUrl_https://www.zillow.com/homedetails/2235-Brentwood-Dr-Houston-TX-77019/27845337_zpid/      0.003300
# dtype: float64

# %% [markdown]
# ### Step 10: Baseline Comparison
# Compare the model's MAE to the average price in the dataset.

# %%
print(f"Average home price: ${Y.mean():,.2f}")
# Out:
# Average home price: $521,595.48

# %% [markdown]
#  **Final Notes:**
# - Model MAE: ~$111,000
#
# - Average Home Price: ~$521,000
# - This means the model is off by ~21%, which is reasonable for real estate price prediction, especially with minimal feature tuning.
